# %% [markdown]
# <a href="https://colab.research.google.com/github/alok-dev115/Machine-Learning-Projects/blob/main/house_price_predictor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
